# %%
import pandas as pd

# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv('GAZPRU.csv', parse_dates=['TradeDateTime'], index_col='TradeDateTime')

# %%
df['NotionalEUR'].plot(figsize=(15,5), title = 'RFQ on GAZPRU')

# %%
ts = pd.Series(df.index)

# %%
time = sorted(ts.astype(int))

# %%
time = np.array(time)
time /= 1e12
time -= time[0]

# %%
from hawkes import ExpectationMaximization

# %%
def inspect(mu, a, b):
        print mu, a, b

ExpectationMaximization(time[:10], niter=10, callback=inspect)
# Out:
# 0.0141819845196 0.0206864693607 -0.010842684062
# 0.0155743200802 0.0160840535598 -0.0170161181336
# 0.0166180692406 0.0155532090851 -0.0176281012184
# 0.0167111149092 0.0155059586466 -0.0176836294257
# 0.0167194645908 0.01550177011 -0.0176885389756
# 0.0167202020897 0.0155014008126 -0.0176889716326
# 0.0167202670765 0.0155013682763 -0.0176890097494
# 0.0167202728018 0.0155013654099 -0.0176890131074
# 0.0167202733061 0.0155013651574 -0.0176890134032
# 0.0167202733506 0.0155013651352 -0.0176890134293
